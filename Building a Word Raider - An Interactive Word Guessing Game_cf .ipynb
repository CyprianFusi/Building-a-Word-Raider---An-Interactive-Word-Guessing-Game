# %% [markdown]
# # Building an Interactive Game - Word Raider
# **Word Raider** is an interactive word-guessing game.
# ## The Rules
# * Prompt the player to guess a **n-letter word**
# * Provide some feedback as to whether the letters within their guess are in the word to guess
# * If the player guesses the **correct letter in the correct position**, that letter will be filled in on the console
# * If they guess a correct letter that belongs in the word, but it is **in the wrong position**, that letter will be added to a list of **misplaced letters, and an underscore will be shown in that position** on the console
# * If they guess a **letter that does not belong in the word**, that letter will be added to a **list of incorrect letters, and an underscore will be shown** in that position on the console.
# * The user will have a **maximum of 5 attempts** to guess the word.
#
# Helper functions and the game logic are implemented in the module `app_function.py`
#
#
# ### Playing the Game...

# %%
from app_functions import word_guessing_game

# %%
word_guessing_game()
# Out:
# Welcome to MR & MRS WORD!
# An Interactive Word-Guessing Game
#
# The word to guess has 3 letters
# You have a maximum of 5 attempts to guess the word...
# Guess a 3-letter word: kings
#
#
# The entered word (kings) is invalid! Try again...
#
# You have 5 attempts remaining...
# Guess a 3-letter word: gym
#
#
# You won 😊 🏆!!
#
# Your guess: gym
# The correct word: gym
#
# Do you wish to start a new game?(Y/N): y
#
# Welcome to MR & MRS WORD!
# An Interactive Word-Guessing Game
#
# The word to guess has 9 letters
# You have a maximum of 5 attempts to guess the word...
# Guess a 9-letter word: functions
#
# _______n_
#
# Misplaced Letters: ['n', 't', 'c']
# Incorrect letters: ['i', 'o', 'f', 'u', 's']
#
# You have 4 attempts remaining...
# Guess a 9-letter word: treatment
#
# ______ent
#
# Misplaced Letters: ['n', 'e', 't', 'c']
# Incorrect letters: ['m', 'i', 'r', 'a', 'o', 'f', 'u', 's']
#
# You have 3 attempts remaining...
# Guess a 9-letter word: excellent
#
#
# You won 😊 🏆!!
#
# Your guess: excellent
# The correct word: excellent
#
# Do you wish to start a new game?(Y/N): y
#
# Welcome to MR & MRS WORD!
# An Interactive Word-Guessing Game
#
# The word to guess has 9 letters
# You have a maximum of 5 attempts to guess the word...
# Guess a 9-letter word: excellent
#
#
# You won 😊 🏆!!
#
# Your guess: excellent
# The correct word: excellent
#
# Do you wish to start a new game?(Y/N): y
#
# Welcome to MR & MRS WORD!
# An Interactive Word-Guessing Game
#
# The word to guess has 8 letters
# You have a maximum of 5 attempts to guess the word...
# Guess a 8-letter word: learning
#
#
# You won 😊 🏆!!
#
# Your guess: learning
# The correct word: learning
#
# Do you wish to start a new game?(Y/N): y
#
# Welcome to MR & MRS WORD!
# An Interactive Word-Guessing Game
#
# The word to guess has 7 letters
# You have a maximum of 5 attempts to guess the word...
# Guess a 7-letter word: machine
#
# ______e
#
# Misplaced Letters: ['i', 'a']
# Incorrect letters: ['m', 'n', 'c', 'h']
#
# You have 4 attempts remaining...
# Guess a 7-letter word: maximum
#
# _______
#
# Misplaced Letters: ['i', 'a']
# Incorrect letters: ['m', 'n', 'h', 'c', 'u', 'x']
#
# You have 3 attempts remaining...
# Guess a 7-letter word: machine
#
# ______e
#
# Misplaced Letters: ['i', 'a']
# Incorrect letters: ['m', 'n', 'h', 'c', 'u', 'x']
#
# You have 2 attempts remaining...
# Guess a 7-letter word: machine
#
# ______e
#
# Misplaced Letters: ['i', 'a']
# Incorrect letters: ['m', 'n', 'h', 'c', 'u', 'x']
#
# You have 1 attempts remaining...
# Guess a 7-letter word: machine
#
# ______e
#
# You did not win 😠!
#
# Your guess: machine
# The correct word: disease
#
#
# Do you wish to start a new game?(Y/N): n
#
# Goodbye 👋 and thanks for playing...
